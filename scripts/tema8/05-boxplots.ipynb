# %% [markdown]
# # Diagrama de Caja y Bigotes

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
np.random.seed(19880519)

# %%
dist1 = 100*np.random.rand(50)
dist2 = 50*np.ones(25)
dist3 = 100+100*np.random.rand(10)
dist4 = -100*np.random.rand(10)
data = np.concatenate((dist1, dist2, dist3, dist4))

# %%
fig1, ax1 = plt.subplots()
ax1.set_title("Boxplot básico")
ax1.boxplot(data)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x11a731eb8>],
#  'caps': [<matplotlib.lines.Line2D at 0x11a73a908>,
#   <matplotlib.lines.Line2D at 0x11a73ad30>],
#  'fliers': [<matplotlib.lines.Line2D at 0x11a7465c0>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x11a746198>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x11a73a048>,
#   <matplotlib.lines.Line2D at 0x11a73a4e0>]}

# %%
fig2, ax2 = plt.subplots()
ax2.set_title("Boxplot con muescas")
ax2.boxplot(data, notch = True)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x11df91f60>],
#  'caps': [<matplotlib.lines.Line2D at 0x11df979b0>,
#   <matplotlib.lines.Line2D at 0x11df97dd8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x11df9c668>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x11df9c240>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x11df970f0>,
#   <matplotlib.lines.Line2D at 0x11df97588>]}

# %%
green_diamond = dict(markerfacecolor="g", marker="D")
fig3, ax3 = plt.subplots()
ax3.set_title("Boxplot con outliers personalizados")
ax3.boxplot(data, flierprops=green_diamond)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x11e031fd0>],
#  'caps': [<matplotlib.lines.Line2D at 0x11e038a20>,
#   <matplotlib.lines.Line2D at 0x11e038e48>],
#  'fliers': [<matplotlib.lines.Line2D at 0x11e03f6d8>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x11e03f2b0>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x11e038160>,
#   <matplotlib.lines.Line2D at 0x11e0385f8>]}

# %%
fig4, ax4 = plt.subplots()
ax4.set_title("Boxplot sin outliers")
ax4.boxplot(data, showfliers=False)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x11e0d6da0>],
#  'caps': [<matplotlib.lines.Line2D at 0x11e0db7f0>,
#   <matplotlib.lines.Line2D at 0x11e0dbc18>],
#  'fliers': [],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x11e0e0080>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x11e0d6ef0>,
#   <matplotlib.lines.Line2D at 0x11e0db3c8>]}

# %%
red_square = dict(markerfacecolor="r", marker="s")
fig5, ax5 = plt.subplots()
ax5.set_title("Boxplot personalizado y en horizontal")
ax5.boxplot(data, vert=False, flierprops=red_square, whis=0.75)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x11e44a048>],
#  'caps': [<matplotlib.lines.Line2D at 0x11e44aa58>,
#   <matplotlib.lines.Line2D at 0x11e44ae80>],
#  'fliers': [<matplotlib.lines.Line2D at 0x11e450710>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x11e4502e8>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x11e44a198>,
#   <matplotlib.lines.Line2D at 0x11e44a630>]}

# %%
dist1 = 100*np.random.rand(50)
dist2 = 40*np.ones(25)
dist3 = 100+100*np.random.rand(10)
dist4 = -100*np.random.rand(10)
data2 = np.concatenate((dist1, dist2, dist3, dist4))

# %%
data.shape = (-1,1)
data2.shape = (-1,1)

# %%
fulldata = [data, data2, data2[::2,0]]

# %%
fig7, ax7 = plt.subplots()
ax7.set_title("Múltiples muestras de diferente naturaleza")
ax7.boxplot(fulldata)
plt.show()
